# 2008-01-01 02:00:00  LEVX 010200Z AUTO 19010KT 6SM 05/04 A3018 RMK ...  VFR
# 2008-01-01 02:30:00  LEVX 010230Z AUTO 24007KT 6SM 03/02 A3015 RMK ...  VFR
# 2008-01-01 03:00:00  LEVX 010300Z AUTO 23006KT 9SM 06/04 A3018 RMK ...  VFR
# ...                                                                ...  ...
# 2020-12-24 21:30:00  LEVX 242130Z 05005KT 020V080 CAVOK 05/05 Q1028...  VFR
# 2020-12-24 22:00:00  LEVX 242200Z 06004KT 030V110 CAVOK 05/04 Q1028...  VFR
# 2020-12-24 22:30:00  LEVX 242230Z 08003KT 340V150 CAVOK 05/04 Q1028...  VFR
# 2020-12-24 23:00:00  LEVX 242300Z 03007KT 360V060 CAVOK 05/04 Q1028...  VFR
# 2020-12-24 23:30:00  LEVX 242330Z 04006KT 340V110 CAVOK 05/04 Q1028...  VFR
#
# [229250 rows x 17 columns]

# %%
from pandas.core.algorithms import value_counts
pd.options.display.max_rows = 999
#station.value_counts()
station=station_all[["temp_o","wxcodes_o"]].astype(str)
station["wxcodes_o"].value_counts(dropna=True,normalize=True)
# Out:
# M                 0.814456
# BCFG              0.046308
# FG                0.020785
# BR                0.014783
# -RA               0.013204
# VCFG              0.008877
# RA                0.008567
# -RA BCFG          0.006626
# RA BCFG           0.005710
# SHRA              0.003612
# -RA BR            0.003477
# RA BR             0.003149
# BCFG -RA          0.002875
# -RA FG            0.002848
# BCFG RA           0.002595
# -DZ               0.002578
# -DZ BCFG          0.002543
# RA FG             0.002386
# PRFG              0.002329
# DZ                0.001972
# BCFG DZ           0.001740
# BCFG -DZ          0.001740
# DZ BCFG           0.001714
# -DZ FG            0.001348
# FG DZ             0.001309
# -DZ BR            0.001243
# -SHRA             0.001243
# BR BCFG           0.001016
# FG -DZ            0.000999
# FG -RA            0.000990
# DZ FG             0.000925
# DZ BR             0.000872
# FG RA             0.000776
# VCSH              0.000563
# -RADZ BCFG        0.000506
# -RA VCFG          0.000502
# BR RA             0.000489
# BR -RA            0.000480
# RA VCFG           0.000458
# +RA BCFG          0.000445
# +RA               0.000419
# -RADZ             0.000384
# +RA FG            0.000353
# TS                0.000332
# BR -DZ            0.000327
# SHRA BCFG         0.000318
# +RA BR            0.000318
# +SHRA             0.000305
# BR DZ             0.000297
# -RA PRFG          0.000288
# PRFG RA           0.000284
# RA PRFG           0.000275
# +DZ FG            0.000270
# -RADZ BR          0.000262
# BCFG BR           0.000253
# VCFG -RA          0.000236
# BCFG -RADZ        0.000236
# FU                0.000231
# TSRA              0.000205
# PRFG -DZ          0.000205
# VCTS              0.000201
# SHRA BR           0.000183
# -DZ VCFG          0.000183
# PRFG -RA          0.000170
# RADZ BCFG         0.000157
# -RADZ FG          0.000157
# SHRA TS           0.000153
# MIFG              0.000153
# DZ VCFG           0.000144
# VCFG RA           0.000144
# TS SHRA           0.000131
# +DZ BR            0.000122
# BR VCFG           0.000105
# PRFG DZ           0.000100
# -SHRA BR          0.000100
# FG -RADZ          0.000100
# RA TS             0.000096
# RADZ              0.000092
# BR PRFG           0.000087
# VCFG -DZ          0.000087
# BCFG +RA          0.000083
# /////             0.000083
# -DZ PRFG          0.000083
# SHRA VCFG         0.000070
# RADZ FG           0.000061
# TS RA             0.000061
# -TSRA             0.000061
# TSRA BCFG         0.000057
# DZ PRFG           0.000052
# -SHRA BCFG        0.000052
# +TSRA             0.000052
# BCFG SHRA         0.000052
# FG +RA            0.000048
# //                0.000044
# +DZ               0.000044
# +DZ BCFG          0.000044
# BCFG DZRA         0.000044
# BR +RA            0.000044
# -SHRA VCTS        0.000039
# RA VCTS           0.000039
# BCFG TS           0.000039
# RA TS BCFG        0.000039
# VCFG DZ           0.000039
# -SHRA TS          0.000039
# BCFG RADZ         0.000039
# TS -SHRA          0.000035
# PRFG +RA          0.000035
# SHGR              0.000031
# RA BR BCFG        0.000031
# HZ                0.000031
# TS BCFG           0.000026
# VCFG BR           0.000026
# -RA TS            0.000026
# -DZRA BCFG        0.000026
# FZFG              0.000026
# SHRA FG           0.000026
# +SHRA BR          0.000026
# +SHRA BCFG        0.000026
# +RA VCFG          0.000026
# TS -RA            0.000022
# VCFG SHRA         0.000022
# -RA BR BCFG       0.000022
# SHRA VCTS         0.000022
# DZRA BCFG         0.000017
# BCFG -DZRA        0.000017
# FG +DZ            0.000017
# TS BR             0.000017
# BCFG MIFG         0.000017
# BCFG +DZ          0.000017
# -RA VCTS          0.000017
# PRFG BR           0.000017
# DZ BR BCFG        0.000017
# nan               0.000013
# BCBR              0.000013
# VCFG BR -RA       0.000013
# -SHRA FG          0.000013
# VCTS -RA          0.000013
# NSW               0.000013
# +SHRA VCFG        0.000013
# RA FZFG           0.000013
# VCTS SHRA         0.000013
# +SHRA TS          0.000013
# SHRA PRFG         0.000013
# BCFG BR -RA       0.000013
# BCFG BR RA        0.000013
# BCFG BR DZ        0.000013
# VCTS BCFG SHRA    0.000009
# BR -RADZ          0.000009
# FG RADZ           0.000009
# TSRA BR           0.000009
# RADZ BR           0.000009
# BR +DZ            0.000009
# +RA TS            0.000009
# FG TSRA           0.000009
# TS VCSH           0.000009
# FG TS             0.000009
# RA TS FG          0.000009
# DZRA BR BCFG      0.000009
# BR SHRA           0.000009
# BR MIFG           0.000009
# BR BCFG -DZ       0.000009
# TS SHGR           0.000009
# +SHGR             0.000009
# SHGS              0.000009
# TS +SHRA          0.000009
# PRFG BR RA        0.000009
# VCTS BCFG RA      0.000004
# VCTS BCFG         0.000004
# VCTS -SHRA        0.000004
# VCRA              0.000004
# +SHRA PRFG        0.000004
# +SHRAGS           0.000004
# TSRA FG           0.000004
# -TSRA -RA         0.000004
# TSSHRA            0.000004
# +SHRA FG          0.000004
# TSGS              0.000004
# +SHRA VCTS        0.000004
# -DZRA FG          0.000004
# -DZRA             0.000004
# -TSRA BCFG        0.000004
# -TSRA BR          0.000004
# +SHGR VCTS        0.000004
# -RA TS VCFG       0.000004
# -SHRA TS BR       0.000004
# TS +SHRA BR       0.000004
# BCFG -SHRA        0.000004
# DZ VCTS           0.000004
# RA BCFG VCTS      0.000004
# TS -DZ            0.000004
# MIFG DZ           0.000004
# TSGR              0.000004
# BR RADZ           0.000004
# BCFG FG           0.000004
# BR RA BCFG        0.000004
# VCFG +RA          0.000004
# RA BCFG BR        0.000004
# FG BCFG           0.000004
# DZ TS             0.000004
# BCFG TS RA        0.000004
# BCFG TS +RA       0.000004
# FG TS -RA         0.000004
# -SHRA VCFG        0.000004
# -RA TS BCFG       0.000004
# SHRA TS BCFG      0.000004
# +TSRA BR          0.000004
# PRFG BCFG         0.000004
# TS BCFG +SHRA     0.000004
# BCFG +SHRA        0.000004
# FG DZRA           0.000004
# Name: wxcodes_o, dtype: float64

# %%
station["brfg_l"]="No BR/FG"
mask=station['wxcodes_o'].str.contains("BR")
station.loc[mask,["brfg_l"]]="BR/FG"
mask=station['wxcodes_o'].str.contains("FG")
station.loc[mask,["brfg_l"]]= "BR/FG"
station=station.drop(columns=["temp_o"])
print(station.value_counts())
print(station.sample(40))
# Out:
# wxcodes_o       brfg_l
# M               No BR/FG    186714
# BCFG            BR/FG        10616
# FG              BR/FG         4765
# BR              BR/FG         3389
# -RA             No BR/FG      3027
# VCFG            BR/FG         2035
# RA              No BR/FG      1964
# -RA BCFG        BR/FG         1519
# RA BCFG         BR/FG         1309
# SHRA            No BR/FG       828
# -RA BR          BR/FG          797
# RA BR           BR/FG          722
# BCFG -RA        BR/FG          659
# -RA FG          BR/FG          653
# BCFG RA         BR/FG          595
# -DZ             No BR/FG       591
# -DZ BCFG        BR/FG          583
# RA FG           BR/FG          547
# PRFG            BR/FG          534
# DZ              No BR/FG       452
# BCFG DZ         BR/FG          399
# BCFG -DZ        BR/FG          399
# DZ BCFG         BR/FG          393
# -DZ FG          BR/FG          309
# FG DZ           BR/FG          300
# -DZ BR          BR/FG          285
# -SHRA           No BR/FG       285
# BR BCFG         BR/FG          233
# FG -DZ          BR/FG          229
# FG -RA          BR/FG          227
# DZ FG           BR/FG          212
# DZ BR           BR/FG          200
# FG RA           BR/FG          178
# VCSH            No BR/FG       129
# -RADZ BCFG      BR/FG          116
# -RA VCFG        BR/FG          115
# BR RA           BR/FG          112
# BR -RA          BR/FG          110
# RA VCFG         BR/FG          105
# +RA BCFG        BR/FG          102
# +RA             No BR/FG        96
# -RADZ           No BR/FG        88
# +RA FG          BR/FG           81
# TS              No BR/FG        76
# BR -DZ          BR/FG           75
# SHRA BCFG       BR/FG           73
# +RA BR          BR/FG           73
# +SHRA           No BR/FG        70
# BR DZ           BR/FG           68
# -RA PRFG        BR/FG           66
# PRFG RA         BR/FG           65
# RA PRFG         BR/FG           63
# +DZ FG          BR/FG           62
# -RADZ BR        BR/FG           60
# BCFG BR         BR/FG           58
# VCFG -RA        BR/FG           54
# BCFG -RADZ      BR/FG           54
# FU              No BR/FG        53
# PRFG -DZ        BR/FG           47
# TSRA            No BR/FG        47
# VCTS            No BR/FG        46
# SHRA BR         BR/FG           42
# -DZ VCFG        BR/FG           42
# PRFG -RA        BR/FG           39
# -RADZ FG        BR/FG           36
# RADZ BCFG       BR/FG           36
# MIFG            BR/FG           35
# SHRA TS         No BR/FG        35
# VCFG RA         BR/FG           33
# DZ VCFG         BR/FG           33
# TS SHRA         No BR/FG        30
# +DZ BR          BR/FG           28
# BR VCFG         BR/FG           24
# PRFG DZ         BR/FG           23
# FG -RADZ        BR/FG           23
# -SHRA BR        BR/FG           23
# RA TS           No BR/FG        22
# RADZ            No BR/FG        21
# BR PRFG         BR/FG           20
# VCFG -DZ        BR/FG           20
=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_st/meteorological_models/lat42.225lon-8.63p10R4KmD1.csv",parse_dates=["time"]).set_index("time")
model4k.columns
# Out:
# Index(['dir0', 'mod0', 'wind_gust0', 'mslp0', 'temp0', 'rh0', 'visibility0',
#        'lhflx0', 'lwflx0', 'conv_prec0',
#        ...
#        'cape9', 'cin9', 'cfh9', 'cfl9', 'cfm9', 'cft9', 'HGT5009', 'HGT8509',
#        'T5009', 'T8509'],
#       dtype='object', length=230)

# %%
#concat station model
df_all4k=pd.concat([station,model4k],axis=1).dropna()
df_all4k=df_all4k.drop(columns=["wxcodes_o"])

# %% [markdown]
# **machine learning d0**

# %%
from pycaret.classification import *
#drop variables model labeled
clas = setup(df_all4k,
             target = 'brfg_l',
             session_id=20,normalize=False ,train_size=.85,remove_multicollinearity=True,
             fix_imbalance=False,ignore_low_variance=True,feature_selection=True,
             feature_selection_threshold =.15,pca=False,polynomial_features=False,
             trigonometry_features=False,feature_interaction=False)
# Out:
#                                Description                  Value
# 0                               session_id                     20
# 1                                   Target                 brfg_l
# 2                              Target Type                 Binary
# 3                            Label Encoded  BR/FG: 0, No BR/FG: 1
# 4                            Original Data          (110932, 231)
# 5                           Missing Values                  False
# 6                         Numeric Features                    230
# 7                     Categorical Features                      0
# 8                         Ordinal Features                  False
# 9                High Cardinality Features                  False
# 10                 High Cardinality Method                   None
# 11                   Transformed Train Set            (94292, 33)
# 12                    Transformed Test Set            (16640, 33)
# 13                      Shuffle Train-Test                   True
# 14                     Stratify Train-Test                  False
# 15                          Fold Generator        StratifiedKFold
# 16                             Fold Number                     10
# 17                                CPU Jobs                     -1
# 18                                 Use GPU                  False
# 19                          Log Experiment                  False
# 20                         Experiment Name       clf-default-name
# 21                                     USI                   8603
# 22                         Imputation Type                 simple
# 23          Iterative Imputation Iteration                   None
# 24                         Numeric Imputer                   mean
# 25      Iterative Imputation Numeric Model                   None
# 26                     Categorical Imputer               constant
# 27  Iterative Imputation Categorical Model                   None
# 28           Unknown Categoricals Handling         least_frequent
# 29                               Normalize                  False
# 30                        Normalize Method                   None
# 31                          Transformation                  False
# 32                   Transformation Method                   None
# 33                                     PCA                  False
# 34                              PCA Method                   None
# 35                          PCA Components                   None
# 36                     Ignore Low Variance                   True
# 37                     Combine Rare Levels                  False
# 38                    Rare Level Threshold                   None
# 39                         Numeric Binning                  False
# 40                         Remove Outliers                  False
# 41                      Outliers Threshold                   None
# 42                Remove Multicollinearity                   True
# 43             Multicollinearity Threshold                    0.9
# 44             Remove Perfect Collinearity                   True
# 45                              Clustering                  False
# 46                    Clustering Iteration                   None
# 47                     Polynomial Features                  False
# 48                       Polynomial Degree                   None
# 49                    Trignometry Features                  False
# 50                    Polynomial Threshold                   None
# 51                          Group Features                  False
# 52                       Feature Selection                   True
# 53                Feature Selection Method                classic
# 54            Features Selection Threshold                   0.15
# 55                     Feature Interaction                  False
# 56                           Feature Ratio                  False
# 57                   Interaction Threshold                   None
# 58                           Fix Imbalance                  False
# 59                    Fix Imbalance Method                  SMOTE

# %%
compare_models(fold=5,sort="F1")
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8904  0.8810  0.9792  0.9023
# rf               Random Forest Classifier    0.8899  0.8721  0.9801  0.9010
# lightgbm  Light Gradient Boosting Machine    0.8868  0.8729  0.9775  0.9000
# gbc          Gradient Boosting Classifier    0.8844  0.8594  0.9760  0.8988
# ada                  Ada Boost Classifier    0.8772  0.8465  0.9668  0.8987
# lr                    Logistic Regression    0.8681  0.7833  0.9820  0.8794
# ridge                    Ridge Classifier    0.8663  0.0000  0.9855  0.8754
# dummy                    Dummy Classifier    0.8637  0.5000  1.0000  0.8637
# svm                   SVM - Linear Kernel    0.8641  0.0000  0.9798  0.8773
# lda          Linear Discriminant Analysis    0.8610  0.8118  0.9499  0.8956
# knn                K Neighbors Classifier    0.8556  0.7499  0.9536  0.8875
# qda       Quadratic Discriminant Analysis    0.8321  0.8014  0.8927  0.9111
# dt               Decision Tree Classifier    0.8308  0.6560  0.8963  0.9067
# nb                            Naive Bayes    0.8039  0.7929  0.8512  0.9158
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9392  0.3978  0.4350    12.258
# rf        0.9389  0.3890  0.4289    36.326
# lightgbm  0.9372  0.3759  0.4122     2.304
# gbc       0.9358  0.3631  0.3979    76.774
# ada       0.9315  0.3461  0.3694    15.024
# lr        0.9279  0.1869  0.2385    12.960
# ridge     0.9272  0.1455  0.2022     0.146
# dummy     0.9269  0.0000  0.0000     0.108
# svm       0.9257  0.1574  0.2033     6.514
# lda       0.9219  0.2958  0.3069     0.572
# knn       0.9194  0.2346  0.2496    89.168
# qda       0.9018  0.3235  0.3243     0.318
# dt        0.9015  0.3028  0.3030     3.832
# nb        0.8823  0.2992  0.3065     0.162
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=20, verbose=0,
#                      warm_start=False)

# %%
model=create_model("lightgbm",n_estimators=150,fold=5)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8888  0.8774  0.9771  0.9023  0.9382  0.3936  0.4276
# 1       0.8866  0.8725  0.9755  0.9013  0.9369  0.3828  0.4151
# 2       0.8850  0.8738  0.9764  0.8991  0.9362  0.3664  0.4015
# 3       0.8891  0.8762  0.9801  0.9003  0.9385  0.3832  0.4234
# 4       0.8874  0.8742  0.9756  0.9021  0.9374  0.3889  0.4208
# Mean    0.8874  0.8748  0.9769  0.9010  0.9374  0.3830  0.4177
# SD      0.0015  0.0017  0.0017  0.0012  0.0009  0.0092  0.0091

# %%
plot_model(model, plot = 'auc')

# %%
plot_model(model, plot = 'pr')

# %%
plot_model(model,'confusion_matrix')

# %%
plot_model(model,'class_report')

# %%
plot_model(model,"feature")

# %%
plot_model(model,"error")

# %% [markdown]
# **improved?**

# %%
from pycaret.classification import *
#drop variables model labeled
clas = setup(df_all4k,
             target = 'brfg_l',
             session_id=20,normalize=True ,train_size=.85,remove_multicollinearity=True,
             fix_imbalance=False,ignore_low_variance=True,feature_selection=True,
             feature_selection_threshold =.15,pca=True,pca_components=10, polynomial_features=False,
             trigonometry_features=False,feature_interaction=False)
# Out:
#                                Description                  Value
# 0                               session_id                     20
# 1                                   Target                 brfg_l
# 2                              Target Type                 Binary
# 3                            Label Encoded  BR/FG: 0, No BR/FG: 1
# 4                            Original Data          (110932, 231)
# 5                           Missing Values                  False
# 6                         Numeric Features                    230
# 7                     Categorical Features                      0
# 8                         Ordinal Features                  False
# 9                High Cardinality Features                  False
# 10                 High Cardinality Method                   None
# 11                   Transformed Train Set            (94292, 10)
# 12                    Transformed Test Set            (16640, 10)
# 13                      Shuffle Train-Test                   True
# 14                     Stratify Train-Test                  False
# 15                          Fold Generator        StratifiedKFold
# 16                             Fold Number                     10
# 17                                CPU Jobs                     -1
# 18                                 Use GPU                  False
# 19                          Log Experiment                  False
# 20                         Experiment Name       clf-default-name
# 21                                     USI                   06bf
# 22                         Imputation Type                 simple
# 23          Iterative Imputation Iteration                   None
# 24                         Numeric Imputer                   mean
# 25      Iterative Imputation Numeric Model                   None
# 26                     Categorical Imputer               constant
# 27  Iterative Imputation Categorical Model                   None
# 28           Unknown Categoricals Handling         least_frequent
# 29                               Normalize                   True
# 30                        Normalize Method                 zscore
# 31                          Transformation                  False
# 32                   Transformation Method                   None
# 33                                     PCA                   True
# 34                              PCA Method                 linear
# 35                          PCA Components                     10
# 36                     Ignore Low Variance                   True
# 37                     Combine Rare Levels                  False
# 38                    Rare Level Threshold                   None
# 39                         Numeric Binning                  False
# 40                         Remove Outliers                  False
# 41                      Outliers Threshold                   None
# 42                Remove Multicollinearity                   True
# 43             Multicollinearity Threshold                    0.9
# 44             Remove Perfect Collinearity                   True
# 45                              Clustering                  False
# 46                    Clustering Iteration                   None
# 47                     Polynomial Features                  False
# 48                       Polynomial Degree                   None
# 49                    Trignometry Features                  False
# 50                    Polynomial Threshold                   None
# 51                          Group Features                  False
# 52                       Feature Selection                   True
# 53                Feature Selection Method                classic
# 54            Features Selection Threshold                   0.15
# 55                     Feature Interaction                  False
# 56                           Feature Ratio                  False
# 57                   Interaction Threshold                   None
# 58                           Fix Imbalance                  False
# 59                    Fix Imbalance Method                  SMOTE

# %%
compare_models(fold=5,sort="F1")
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8837  0.8515  0.9781  0.8966
# rf               Random Forest Classifier    0.8823  0.8459  0.9784  0.8951
# lightgbm  Light Gradient Boosting Machine    0.8804  0.8454  0.9789  0.8930
# gbc          Gradient Boosting Classifier    0.8781  0.8338  0.9825  0.8882
# knn                K Neighbors Classifier    0.8717  0.7853  0.9538  0.9031
# lr                    Logistic Regression    0.8676  0.8000  0.9842  0.8774
# dummy                    Dummy Classifier    0.8637  0.5000  1.0000  0.8637
# ridge                    Ridge Classifier    0.8649  0.0000  0.9863  0.8736
# svm                   SVM - Linear Kernel    0.8637  0.0000  0.9938  0.8678
# ada                  Ada Boost Classifier    0.8661  0.8143  0.9729  0.8838
# lda          Linear Discriminant Analysis    0.8597  0.7944  0.9540  0.8912
# qda       Quadratic Discriminant Analysis    0.8240  0.7927  0.8839  0.9098
# dt               Decision Tree Classifier    0.8217  0.6368  0.8911  0.9014
# nb                            Naive Bayes    0.8138  0.7700  0.8806  0.9015
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9356  0.3476  0.3872     9.284
# rf        0.9349  0.3352  0.3763    27.724
# lightgbm  0.9339  0.3168  0.3600     1.192
# gbc       0.9330  0.2779  0.3308    31.212
# knn       0.9278  0.3590  0.3700     4.518
# lr        0.9277  0.1676  0.2233     0.444
# dummy     0.9269  0.0000  0.0000     0.106
# ridge     0.9265  0.1247  0.1804     0.118
# svm       0.9264  0.0447  0.0500     0.448
# ada       0.9262  0.2223  0.2576     6.608
# lda       0.9215  0.2659  0.2805     0.226
# qda       0.8967  0.3055  0.3070     0.150
# dt        0.8962  0.2654  0.2656     1.468
# nb        0.8909  0.2552  0.2560     0.126
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=20, verbose=0,
#                      warm_start=False)

# %%
model=create_model("lightgbm",n_estimators=150,fold=5)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8809  0.8488  0.9779  0.8941  0.9341  0.3253  0.3660
# 1       0.8801  0.8430  0.9762  0.8946  0.9336  0.3273  0.3648
# 2       0.8805  0.8434  0.9781  0.8935  0.9339  0.3210  0.3624
# 3       0.8807  0.8516  0.9790  0.8932  0.9341  0.3187  0.3620
# 4       0.8806  0.8435  0.9779  0.8938  0.9340  0.3227  0.3636
# Mean    0.8806  0.8460  0.9778  0.8938  0.9340  0.3230  0.3638
# SD      0.0003  0.0035  0.0009  0.0005  0.0002  0.0030  0.0015

# %%
plot_model(model,'confusion_matrix')

# %%
plot_model(model,'class_report')

# %%
model=create_model("mlp",fold=5)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8806  0.8470  0.9757  0.8955  0.9339  0.3340  0.3703
# 1       0.8804  0.8456  0.9733  0.8970  0.9336  0.3433  0.3751
# 2       0.8823  0.8452  0.9757  0.8970  0.9347  0.3477  0.3831
# 3       0.8817  0.8513  0.9785  0.8945  0.9346  0.3295  0.3710
# 4       0.8815  0.8453  0.9779  0.8947  0.9344  0.3303  0.3707
# Mean    0.8813  0.8469  0.9762  0.8957  0.9342  0.3369  0.3740
# SD      0.0007  0.0023  0.0018  0.0011  0.0004  0.0073  0.0049

# %%
plot_model(model,'confusion_matrix')

# %%
plot_model(model,'class_report')

# %% [markdown]
# **Export model**

# %%
x_var=get_config("X_train").columns
x_var
# Out:
# Index(['cfl7', 'cin2', 'visibility8', 'dir6', 'cfl6', 'wind_gust6', 'lwflx4',
#        'temp4', 'dir9', 'cfl9', 'dir3', 'cfl1', 'cfl0', 'rh2', 'cfl2', 'cfl3',
#        'visibility3', 'mod4', 'visibility5', 'cfl4', 'lhflx6', 'visibility7',
#        'visibility1', 'dir4', 'visibility0', 'mod2', 'shflx8', 'visibility9',
#        'wind_gust3', 'visibility4', 'dir2', 'visibility2', 'cfl8'],
#       dtype='object')

# %%
#define x and y
Y=df_all4k.brfg_l
X=df_all4k[x_var]

# %%
#Run the machine learning model
from sklearn.ensemble import ExtraTreesClassifier
from lightgbm.sklearn import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.1, random_state=1)
#ml_model=ExtraTreesClassifier(n_estimators=150).fit(X_train,y_train)
ml_model=LGBMClassifier(n_estimators=250).fit(X_train,y_train)

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
cr=pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T
plt.figure(figsize=(12, 9))
plt.title("Quality report (Machine Learning)")
sns.heatmap(cr[:-3].drop(columns=["support"]),annot=True,cmap="YlGnBu",fmt='.0%');

# %%
plt.figure(figsize=(8, 6))
plt.title("Confusion matrix (Machine Learning)")
import seaborn as sns
global_sc=pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
sns.heatmap(global_sc,annot=True,cmap="YlGnBu",fmt='.0f');

# %%
import math
from scipy.stats import entropy
plt.figure(figsize=(12, 9))
plt.title("Machine Learning precision and entropy")
column_sc=pd.crosstab(y_test, ml_model.predict(X_test), margins=True,normalize="columns")
column_sc=column_sc.append(pd.DataFrame(entropy(column_sc,base=2)/(math.log2(column_sc.shape[0])),columns=["entropy/entropy.max"],
                    index=column_sc.columns).T).rename(columns={"All":"Climatology"})
sns.heatmap(column_sc,annot=True,cmap="YlGnBu",fmt='.0%');

# %%
import pickle
model_dict={"x_var":x_var,"ml_model":ml_model,"coor":coor}
pickle.dump(model_dict, open("brfg_LEVX_d1.al", 'wb'))
