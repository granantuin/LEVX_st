#                                                                metar_o fr_o
# time
# 2008-01-01 00:00:00  LEVX 010000Z AUTO 22007KT 9SM 05/05 A3021 RMK ...  VFR
# 2008-01-01 01:00:00  LEVX 010100Z AUTO 23006KT 05/04 RMK SLP235 T00...  VFR
# 2008-01-01 02:00:00  LEVX 010200Z AUTO 19010KT 6SM 05/04 A3018 RMK ...  VFR
# 2008-01-01 02:30:00  LEVX 010230Z AUTO 24007KT 6SM 03/02 A3015 RMK ...  VFR
# 2008-01-01 03:00:00  LEVX 010300Z AUTO 23006KT 9SM 06/04 A3018 RMK ...  VFR
# ...                                                                ...  ...
# 2020-12-24 21:30:00  LEVX 242130Z 05005KT 020V080 CAVOK 05/05 Q1028...  VFR
# 2020-12-24 22:00:00  LEVX 242200Z 06004KT 030V110 CAVOK 05/04 Q1028...  VFR
# 2020-12-24 22:30:00  LEVX 242230Z 08003KT 340V150 CAVOK 05/04 Q1028...  VFR
# 2020-12-24 23:00:00  LEVX 242300Z 03007KT 360V060 CAVOK 05/04 Q1028...  VFR
# 2020-12-24 23:30:00  LEVX 242330Z 04006KT 340V110 CAVOK 05/04 Q1028...  VFR
#
# [229250 rows x 17 columns]

# %%
from pandas.core.algorithms import value_counts
pd.options.display.max_rows = 999
#station.value_counts()
station=station_all[["temp_o","wxcodes_o"]].astype(str)
station["wxcodes_o"].value_counts(dropna=True,normalize=True)
# Out:
# M                 0.814456
# BCFG              0.046308
# FG                0.020785
# BR                0.014783
# -RA               0.013204
# VCFG              0.008877
# RA                0.008567
# -RA BCFG          0.006626
# RA BCFG           0.005710
# SHRA              0.003612
# -RA BR            0.003477
# RA BR             0.003149
# BCFG -RA          0.002875
# -RA FG            0.002848
# BCFG RA           0.002595
# -DZ               0.002578
# -DZ BCFG          0.002543
# RA FG             0.002386
# PRFG              0.002329
# DZ                0.001972
# BCFG DZ           0.001740
# BCFG -DZ          0.001740
# DZ BCFG           0.001714
# -DZ FG            0.001348
# FG DZ             0.001309
# -DZ BR            0.001243
# -SHRA             0.001243
# BR BCFG           0.001016
# FG -DZ            0.000999
# FG -RA            0.000990
# DZ FG             0.000925
# DZ BR             0.000872
# FG RA             0.000776
# VCSH              0.000563
# -RADZ BCFG        0.000506
# -RA VCFG          0.000502
# BR RA             0.000489
# BR -RA            0.000480
# RA VCFG           0.000458
# +RA BCFG          0.000445
# +RA               0.000419
# -RADZ             0.000384
# +RA FG            0.000353
# TS                0.000332
# BR -DZ            0.000327
# SHRA BCFG         0.000318
# +RA BR            0.000318
# +SHRA             0.000305
# BR DZ             0.000297
# -RA PRFG          0.000288
# PRFG RA           0.000284
# RA PRFG           0.000275
# +DZ FG            0.000270
# -RADZ BR          0.000262
# BCFG BR           0.000253
# VCFG -RA          0.000236
# BCFG -RADZ        0.000236
# FU                0.000231
# TSRA              0.000205
# PRFG -DZ          0.000205
# VCTS              0.000201
# SHRA BR           0.000183
# -DZ VCFG          0.000183
# PRFG -RA          0.000170
# RADZ BCFG         0.000157
# -RADZ FG          0.000157
# SHRA TS           0.000153
# MIFG              0.000153
# DZ VCFG           0.000144
# VCFG RA           0.000144
# TS SHRA           0.000131
# +DZ BR            0.000122
# BR VCFG           0.000105
# PRFG DZ           0.000100
# -SHRA BR          0.000100
# FG -RADZ          0.000100
# RA TS             0.000096
# RADZ              0.000092
# BR PRFG           0.000087
# VCFG -DZ          0.000087
# BCFG +RA          0.000083
# /////             0.000083
# -DZ PRFG          0.000083
# SHRA VCFG         0.000070
# RADZ FG           0.000061
# TS RA             0.000061
# -TSRA             0.000061
# TSRA BCFG         0.000057
# DZ PRFG           0.000052
# -SHRA BCFG        0.000052
# +TSRA             0.000052
# BCFG SHRA         0.000052
# FG +RA            0.000048
# //                0.000044
# +DZ               0.000044
# +DZ BCFG          0.000044
# BCFG DZRA         0.000044
# BR +RA            0.000044
# -SHRA VCTS        0.000039
# RA VCTS           0.000039
# BCFG TS           0.000039
# RA TS BCFG        0.000039
# VCFG DZ           0.000039
# -SHRA TS          0.000039
# BCFG RADZ         0.000039
# TS -SHRA          0.000035
# PRFG +RA          0.000035
# SHGR              0.000031
# RA BR BCFG        0.000031
# HZ                0.000031
# TS BCFG           0.000026
# VCFG BR           0.000026
# -RA TS            0.000026
# -DZRA BCFG        0.000026
# FZFG              0.000026
# SHRA FG           0.000026
# +SHRA BR          0.000026
# +SHRA BCFG        0.000026
# +RA VCFG          0.000026
# TS -RA            0.000022
# VCFG SHRA         0.000022
# -RA BR BCFG       0.000022
# SHRA VCTS         0.000022
# DZRA BCFG         0.000017
# BCFG -DZRA        0.000017
# FG +DZ            0.000017
# TS BR             0.000017
# BCFG MIFG         0.000017
# BCFG +DZ          0.000017
# -RA VCTS          0.000017
# PRFG BR           0.000017
# DZ BR BCFG        0.000017
# nan               0.000013
# BCBR              0.000013
# VCFG BR -RA       0.000013
# -SHRA FG          0.000013
# VCTS -RA          0.000013
# NSW               0.000013
# +SHRA VCFG        0.000013
# RA FZFG           0.000013
# VCTS SHRA         0.000013
# +SHRA TS          0.000013
# SHRA PRFG         0.000013
# BCFG BR -RA       0.000013
# BCFG BR RA        0.000013
# BCFG BR DZ        0.000013
# VCTS BCFG SHRA    0.000009
# BR -RADZ          0.000009
# FG RADZ           0.000009
# TSRA BR           0.000009
# RADZ BR           0.000009
# BR +DZ            0.000009
# +RA TS            0.000009
# FG TSRA           0.000009
# TS VCSH           0.000009
# FG TS             0.000009
# RA TS FG          0.000009
# DZRA BR BCFG      0.000009
# BR SHRA           0.000009
# BR MIFG           0.000009
# BR BCFG -DZ       0.000009
# TS SHGR           0.000009
# +SHGR             0.000009
# SHGS              0.000009
# TS +SHRA          0.000009
# PRFG BR RA        0.000009
# VCTS BCFG RA      0.000004
# VCTS BCFG         0.000004
# VCTS -SHRA        0.000004
# VCRA              0.000004
# +SHRA PRFG        0.000004
# +SHRAGS           0.000004
# TSRA FG           0.000004
# -TSRA -RA         0.000004
# TSSHRA            0.000004
# +SHRA FG          0.000004
# TSGS              0.000004
# +SHRA VCTS        0.000004
# -DZRA FG          0.000004
# -DZRA             0.000004
# -TSRA BCFG        0.000004
# -TSRA BR          0.000004
# +SHGR VCTS        0.000004
# -RA TS VCFG       0.000004
# -SHRA TS BR       0.000004
# TS +SHRA BR       0.000004
# BCFG -SHRA        0.000004
# DZ VCTS           0.000004
# RA BCFG VCTS      0.000004
# TS -DZ            0.000004
# MIFG DZ           0.000004
# TSGR              0.000004
# BR RADZ           0.000004
# BCFG FG           0.000004
# BR RA BCFG        0.000004
# VCFG +RA          0.000004
# RA BCFG BR        0.000004
# FG BCFG           0.000004
# DZ TS             0.000004
# BCFG TS RA        0.000004
# BCFG TS +RA       0.000004
# FG TS -RA         0.000004
# -SHRA VCFG        0.000004
# -RA TS BCFG       0.000004
# SHRA TS BCFG      0.000004
# +TSRA BR          0.000004
# PRFG BCFG         0.000004
# TS BCFG +SHRA     0.000004
# BCFG +SHRA        0.000004
# FG DZRA           0.000004
# Name: wxcodes_o, dtype: float64

# %%
station["prec_l"]="No RA/DZ"
mask=station['wxcodes_o'].str.contains("RA")
station.loc[mask,["prec_l"]]="RA/DZ"
mask=station['wxcodes_o'].str.contains("DZ")
station.loc[mask,["prec_l"]]= "RA/DZ"
station=station.drop(columns=["temp_o"])
print(station.value_counts())
print(station.sample(40))
# Out:
# wxcodes_o       prec_l
# M               No RA/DZ    186714
# BCFG            No RA/DZ     10616
# FG              No RA/DZ      4765
# BR              No RA/DZ      3389
# -RA             RA/DZ         3027
# VCFG            No RA/DZ      2035
# RA              RA/DZ         1964
# -RA BCFG        RA/DZ         1519
# RA BCFG         RA/DZ         1309
# SHRA            RA/DZ          828
# -RA BR          RA/DZ          797
# RA BR           RA/DZ          722
# BCFG -RA        RA/DZ          659
# -RA FG          RA/DZ          653
# BCFG RA         RA/DZ          595
# -DZ             RA/DZ          591
# -DZ BCFG        RA/DZ          583
# RA FG           RA/DZ          547
# PRFG            No RA/DZ       534
# DZ              RA/DZ          452
# BCFG DZ         RA/DZ          399
# BCFG -DZ        RA/DZ          399
# DZ BCFG         RA/DZ          393
# -DZ FG          RA/DZ          309
# FG DZ           RA/DZ          300
# -DZ BR          RA/DZ          285
# -SHRA           RA/DZ          285
# BR BCFG         No RA/DZ       233
# FG -DZ          RA/DZ          229
# FG -RA          RA/DZ          227
# DZ FG           RA/DZ          212
# DZ BR           RA/DZ          200
# FG RA           RA/DZ          178
# VCSH            No RA/DZ       129
# -RADZ BCFG      RA/DZ          116
# -RA VCFG        RA/DZ          115
# BR RA           RA/DZ          112
# BR -RA          RA/DZ          110
# RA VCFG         RA/DZ          105
# +RA BCFG        RA/DZ          102
# +RA             RA/DZ           96
# -RADZ           RA/DZ           88
# +RA FG          RA/DZ           81
# TS              No RA/DZ        76
# BR -DZ          RA/DZ           75
# SHRA BCFG       RA/DZ           73
# +RA BR          RA/DZ           73
# +SHRA           RA/DZ           70
# BR DZ           RA/DZ           68
# -RA PRFG        RA/DZ           66
# PRFG RA         RA/DZ           65
# RA PRFG         RA/DZ           63
# +DZ FG          RA/DZ           62
# -RADZ BR        RA/DZ           60
# BCFG BR         No RA/DZ        58
# VCFG -RA        RA/DZ           54
# BCFG -RADZ      RA/DZ           54
# FU              No RA/DZ        53
# PRFG -DZ        RA/DZ           47
# TSRA            RA/DZ           47
# VCTS            No RA/DZ        46
# SHRA BR         RA/DZ           42
# -DZ VCFG        RA/DZ           42
# PRFG -RA        RA/DZ           39
# -RADZ FG        RA/DZ           36
# RADZ BCFG       RA/DZ           36
# MIFG            No RA/DZ        35
# SHRA TS         RA/DZ           35
# VCFG RA         RA/DZ           33
# DZ VCFG         RA/DZ           33
# TS SHRA         RA/DZ           30
# +DZ BR          RA/DZ           28
# BR VCFG         No RA/DZ        24
# PRFG DZ         RA/DZ           23
# FG -RADZ        RA/DZ           23
# -SHRA BR        RA/DZ           23
# RA TS           RA/DZ           22
# RADZ            RA/DZ           21
# BR PRFG         No RA/DZ        20
# VCFG -DZ        RA/DZ           20
# -DZ PRFG        RA/DZ           19
# /////           No RA/DZ        19
# BCFG +RA        RA/DZ           19
# SHRA VCFG       RA/DZ           16
# RADZ FG         RA/DZ           14
# TS RA           RA/DZ           14
# -TSRA           RA/DZ           14
# TSRA BCFG       RA/DZ           13
# DZ PRFG         RA/DZ           12
# BCFG SHRA       RA/DZ           12
# -SHRA BCFG      RA/DZ           12
# +TSRA           RA/DZ           12
# FG +RA          RA/DZ           11
# +DZ BCFG        RA/DZ           10
# +DZ             RA/DZ           10
# BCFG DZRA       RA/DZ           10
# //              No RA/DZ        10
# BR +RA          RA/DZ           10
# RA TS BCFG      RA/DZ            9
# -SHRA TS        RA/DZ            9
# RA VCTS         RA/DZ            9
# VCFG DZ         RA/DZ            9
# BCFG TS         No RA/DZ         9
# -SHRA VCTS      RA/DZ            9
# BCFG RADZ       RA/DZ            9
# PRFG +RA        RA/DZ            8
# TS -SHRA        RA/DZ            8
# HZ              No RA/DZ         7
# SHGR            No RA/DZ         7
# RA BR BCFG      RA/DZ            7
# TS BCFG         No RA/DZ         6
# SHRA FG         RA/DZ            6
# +RA VCFG        RA/DZ            6
# -RA TS          RA/DZ            6
# +SHRA BR        RA/DZ            6
# FZFG            No RA/DZ         6
# +SHRA BCFG      RA/DZ            6
# VCFG BR         No RA/DZ         6
# -DZRA BCFG      RA/DZ            6
# VCFG SHRA       RA/DZ            5
# -RA BR BCFG     RA/DZ            5
# SHRA VCTS       RA/DZ            5
# TS -RA          RA/DZ            5
# BCFG +DZ        RA/DZ            4
# PRFG BR         No RA/DZ         4
# BCFG MIFG       No RA/DZ         4
# -RA VCTS        RA/DZ            4
# FG +DZ          RA/DZ            4
# DZRA BCFG       RA/DZ            4
# TS BR           No RA/DZ         4
# BCFG -DZRA      RA/DZ            4
# DZ BR BCFG      RA/DZ            4
# +SHRA VCFG      RA/DZ            3
# VCFG BR -RA     RA/DZ            3
# -SHRA FG        RA/DZ            3
# 2010-03-06 20:30:00         M  No RA/DZ
# 2008-01-16 19:30:00         M  No RA/DZ
# 2014-11-09 15:30:00         M  No RA/DZ
# 2018-03-01 09:00:00       -RA     RA/DZ
# 2009-07-11 10:30:00         M  No RA/DZ
# 2016-11-16 00:30:00         M  No RA/DZ
# 2016-06-03 16:30:00         M  No RA/DZ
# 2014-02-28 20:00:00       -DZ     RA/DZ
# 2009-02-19 20:30:00         M  No RA/DZ
# 2013-08-14 05:00:00         M  No RA/DZ
# 2020-10-25 22:30:00         M  No RA/DZ
# 2017-12-24 14:30:00         M  No RA/DZ
# 2009-05-23 21:30:00         M  No RA/DZ
# 2013-05-02 11:30:00         M  No RA/DZ
# 2009-08-18 00:00:00         M  No RA/DZ
# 2017-04-12 03:00:00         M  No RA/DZ
# 2016-10-19 01:00:00         M  No RA/DZ
# 2008-05-16 13:30:00         M  No RA/DZ
# 2013-03-05 23:00:00         M  No RA/DZ
# 2017-08-29 09:00:00     FG DZ     RA/DZ
# 2011-09-30 21:30:00         M  No RA/DZ
# 2008-01-20 21:00:00         M  No RA/DZ
# 2009-04-25 13:00:00         M  No RA/DZ
# 2010-06-23 02:30:00         M  No RA/DZ
# 2018-11-09 06:30:00         M  No RA/DZ
# 2008-09-01 00:30:00         M  No RA/DZ
# 2012-09-29 03:00:00         M  No RA/DZ
# 2016-09-12 21:30:00    +RA BR     RA/DZ
# 2009-06-24 05:30:00         M  No RA/DZ
# 2009-08-21 15:00:00         M  No RA/DZ
# 2017-08-06 23:00:00         M  No RA/DZ
# 2010-12-25 02:30:00         M  No RA/DZ
# 2015-10-05 12:08:00     +SHRA     RA/DZ
# 2009-04-27 21:00:00         M  No RA/DZ
# 2020-10-18 12:30:00         M  No RA/DZ
# 2015-06-14 15:00:00     -SHRA     RA/DZ

# %%
station["prec_l"].value_counts(normalize=True)
# Out:
# No RA/DZ    0.910957
# RA/DZ       0.089043
# Name: prec_l, dtype: float64

# %% [markdown]
# **Forecast D1**

# %%
#ria forecast d1
model4k=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LEVX_st/meteorological_models/lat42.225lon-8.63p10R4KmD1.csv",parse_dates=["time"]).set_index("time")
model4k.columns
# Out:
# Index(['dir0', 'mod0', 'wind_gust0', 'mslp0', 'temp0', 'rh0', 'visibility0',
#        'lhflx0', 'lwflx0', 'conv_prec0',
#        ...
#        'cape9', 'cin9', 'cfh9', 'cfl9', 'cfm9', 'cft9', 'HGT5009', 'HGT8509',
#        'T5009', 'T8509'],
#       dtype='object', length=230)

# %%
#label meteorological model prec points 0 to 9

interval=pd.IntervalIndex.from_tuples([(-1, 0.1), (0.1, 50000)])
labels=["No RA/DZ","RA/DZ"]
model4k["prec0_l"]=pd.cut(model4k["prec0"], bins=interval,retbins=False,labels=labels)

# %%
#label meteorological model prec points 0 to 9
interval=pd.IntervalIndex.from_tuples([(-1, 0.1), (0.1, 50000)])
labels=["No RA/DZ","RA/DZ"]
model4k["prec0_l"]=pd.cut(model4k["prec0"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)
model4k["prec1_l"]=pd.cut(model4k["prec1"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)
model4k["prec2_l"]=pd.cut(model4k["prec2"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)
model4k["prec3_l"]=pd.cut(model4k["prec3"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)
model4k["prec4_l"]=pd.cut(model4k["prec4"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)
model4k["prec5_l"]=pd.cut(model4k["prec5"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)
model4k["prec6_l"]=pd.cut(model4k["prec6"], bins=interval,retbins=False,labels=labels).map({a:b for a,b in zip(interval,labels)}).astype(str)

# %%
#concat station model
df_all4k=pd.concat([station,model4k],axis=1).dropna()
df_all4k=df_all4k.drop(columns=["wxcodes_o"])
df_all4k[["prec_l","prec0_l","prec1_l"]].sample(20)
# Out:
#                        prec_l   prec0_l   prec1_l
# time
# 2013-03-14 08:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2017-04-12 19:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2015-10-07 20:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2019-07-19 18:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2013-05-09 01:00:00     RA/DZ  No RA/DZ  No RA/DZ
# 2012-01-20 14:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2017-04-16 10:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2012-03-08 05:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2008-08-09 13:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2019-03-26 20:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2018-07-21 06:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2011-02-25 18:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2019-10-25 18:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2010-08-13 17:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2009-08-04 12:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2009-02-03 22:00:00  No RA/DZ     RA/DZ     RA/DZ
# 2008-08-06 12:00:00  No RA/DZ  No RA/DZ  No RA/DZ
# 2008-02-05 01:00:00  No RA/DZ     RA/DZ     RA/DZ
# 2018-03-29 13:00:00     RA/DZ     RA/DZ     RA/DZ
# 2010-04-26 03:00:00  No RA/DZ  No RA/DZ  No RA/DZ

# %%
print("station\n",df_all4k["prec_l"].value_counts())
print("point 0\n",df_all4k["prec0_l"].value_counts())
print("point 1\n",df_all4k["prec1_l"].value_counts())
print("point 2\n",df_all4k["prec2_l"].value_counts())
print("point 3\n",df_all4k["prec3_l"].value_counts())
print("point 4\n",df_all4k["prec4_l"].value_counts())
print("point 5\n",df_all4k["prec5_l"].value_counts())
# Out:
# station
#  No RA/DZ    102350
# RA/DZ         8582
# Name: prec_l, dtype: int64
# point 0
#  No RA/DZ    86954
# RA/DZ       23978
# Name: prec0_l, dtype: int64
# point 1
#  No RA/DZ    88581
# RA/DZ       22351
# Name: prec1_l, dtype: int64
# point 2
#  No RA/DZ    88885
# RA/DZ       22047
# Name: prec2_l, dtype: int64
# point 3
#  No RA/DZ    89073
# RA/DZ       21859
# Name: prec3_l, dtype: int64
# point 4
#  No RA/DZ    88541
# RA/DZ       22391
# Name: prec4_l, dtype: int64
# point 5
#  No RA/DZ    89852
# RA/DZ       21080
# Name: prec5_l, dtype: int64

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))
plt.title("Quality report (meteorological model)")
import seaborn as sns
cr=pd.DataFrame(classification_report(df_all4k.prec_l, df_all4k.prec0_l,output_dict=True)).T
sns.heatmap(cr[:-3].drop(columns=["support"]),annot=True,cmap="YlGnBu",fmt='.0%');

# %%
plt.figure(figsize=(8, 6))
plt.title("global quality report (meteorological model)")
sns.heatmap(cr[-3:].drop(columns=["support"]),annot=True,cmap="YlGnBu",fmt='.1%');

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 9))
plt.title("Confusión matrix  (meteorological model)")

global_sc=pd.crosstab(df_all4k.prec_l, df_all4k.prec0_l,margins=True,)
sns.heatmap(global_sc,annot=True,cmap="YlGnBu",fmt='.0f');

# %%
import math
from scipy.stats import entropy
plt.figure(figsize=(12, 9))
plt.title("Meteorological model precision and entropy")
column_sc=pd.crosstab(df_all4k.prec_l, df_all4k.prec0_l, margins=True,normalize="columns")
column_sc=column_sc.append(pd.DataFrame(entropy(column_sc,base=2)/(math.log2(column_sc.shape[0])),columns=["entropia/entropia.max"],
                    index=column_sc.columns).T).rename(columns={"All":"Climatology"})
sns.heatmap(column_sc,annot=True,cmap="YlGnBu",fmt='.0%');

# %% [markdown]
# **machine learning d0 or d1**

# %%
from pycaret.classification import *
#drop variables model labeled
clas = setup(df_all4k.drop(columns=["prec0_l","prec1_l","prec2_l",
                                    "prec3_l","prec4_l","prec5_l",
                                    "prec6_l"]),
             target = 'prec_l',
             session_id=20,normalize=False ,train_size=.85,remove_multicollinearity=True,
             fix_imbalance=False,ignore_low_variance=True,feature_selection=True,
             feature_selection_threshold =.15,pca=False,polynomial_features=False,
             trigonometry_features=False,feature_interaction=False)
# Out:
#                                Description                  Value
# 0                               session_id                     20
# 1                                   Target                 prec_l
# 2                              Target Type                 Binary
# 3                            Label Encoded  No RA/DZ: 0, RA/DZ: 1
# 4                            Original Data          (110932, 231)
# 5                           Missing Values                  False
# 6                         Numeric Features                    230
# 7                     Categorical Features                      0
# 8                         Ordinal Features                  False
# 9                High Cardinality Features                  False
# 10                 High Cardinality Method                   None
# 11                   Transformed Train Set            (94292, 27)
# 12                    Transformed Test Set            (16640, 27)
# 13                      Shuffle Train-Test                   True
# 14                     Stratify Train-Test                  False
# 15                          Fold Generator        StratifiedKFold
# 16                             Fold Number                     10
# 17                                CPU Jobs                     -1
# 18                                 Use GPU                  False
# 19                          Log Experiment                  False
# 20                         Experiment Name       clf-default-name
# 21                                     USI                   51aa
# 22                         Imputation Type                 simple
# 23          Iterative Imputation Iteration                   None
# 24                         Numeric Imputer                   mean
# 25      Iterative Imputation Numeric Model                   None
# 26                     Categorical Imputer               constant
# 27  Iterative Imputation Categorical Model                   None
# 28           Unknown Categoricals Handling         least_frequent
# 29                               Normalize                  False
# 30                        Normalize Method                   None
# 31                          Transformation                  False
# 32                   Transformation Method                   None
# 33                                     PCA                  False
# 34                              PCA Method                   None
# 35                          PCA Components                   None
# 36                     Ignore Low Variance                   True
# 37                     Combine Rare Levels                  False
# 38                    Rare Level Threshold                   None
# 39                         Numeric Binning                  False
# 40                         Remove Outliers                  False
# 41                      Outliers Threshold                   None
# 42                Remove Multicollinearity                   True
# 43             Multicollinearity Threshold                    0.9
# 44             Remove Perfect Collinearity                   True
# 45                              Clustering                  False
# 46                    Clustering Iteration                   None
# 47                     Polynomial Features                  False
# 48                       Polynomial Degree                   None
# 49                    Trignometry Features                  False
# 50                    Polynomial Threshold                   None
# 51                          Group Features                  False
# 52                       Feature Selection                   True
# 53                Feature Selection Method                classic
# 54            Features Selection Threshold                   0.15
# 55                     Feature Interaction                  False
# 56                           Feature Ratio                  False
# 57                   Interaction Threshold                   None
# 58                           Fix Imbalance                  False
# 59                    Fix Imbalance Method                  SMOTE

# %%
compare_models(fold=5,sort="F1")
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9354  0.9226  0.3235  0.6637
# ada                  Ada Boost Classifier    0.9306  0.9086  0.3286  0.5860
# et                 Extra Trees Classifier    0.9361  0.9206  0.3001  0.6942
# rf               Random Forest Classifier    0.9363  0.9173  0.2960  0.7024
# gbc          Gradient Boosting Classifier    0.9344  0.9174  0.3036  0.6583
# lda          Linear Discriminant Analysis    0.9159  0.8709  0.3434  0.4398
# dt               Decision Tree Classifier    0.8995  0.6632  0.3841  0.3566
# nb                            Naive Bayes    0.8037  0.8499  0.7372  0.2433
# qda       Quadratic Discriminant Analysis    0.7882  0.8285  0.7328  0.2274
# knn                K Neighbors Classifier    0.9162  0.7762  0.1951  0.4060
# lr                    Logistic Regression    0.9266  0.8583  0.1645  0.5812
# svm                   SVM - Linear Kernel    0.7622  0.0000  0.2676  0.2516
# ridge                    Ridge Classifier    0.9241  0.0000  0.0394  0.5851
# dummy                    Dummy Classifier    0.9232  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.4348  0.4049  0.4346     1.766
# ada       0.4211  0.3873  0.4057    10.270
# et        0.4188  0.3906  0.4295    10.858
# rf        0.4163  0.3885  0.4296    31.638
# gbc       0.4153  0.3855  0.4183    51.516
# lda       0.3856  0.3412  0.3443     0.436
# dt        0.3698  0.3153  0.3155     2.936
# nb        0.3659  0.2831  0.3444     0.146
# qda       0.3471  0.2604  0.3244     0.262
# knn       0.2635  0.2249  0.2420    43.654
# lr        0.2557  0.2296  0.2817    11.118
# svm       0.1389  0.0856  0.1078     5.398
# ridge     0.0737  0.0646  0.1372     0.136
# dummy     0.0000  0.0000  0.0000     0.102
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=20, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model=create_model("lightgbm",n_estimators=150,fold=5)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9363  0.9255  0.3347  0.6717  0.4468  0.4170  0.4457
# 1       0.9340  0.9207  0.3354  0.6328  0.4384  0.4069  0.4301
# 2       0.9366  0.9190  0.3370  0.6740  0.4494  0.4196  0.4482
# 3       0.9356  0.9256  0.3108  0.6747  0.4255  0.3963  0.4300
# 4       0.9360  0.9247  0.3301  0.6685  0.4420  0.4121  0.4412
# Mean    0.9357  0.9231  0.3296  0.6644  0.4404  0.4104  0.4390
# SD      0.0009  0.0027  0.0097  0.0159  0.0083  0.0083  0.0077

# %%
plot_model(model, plot = 'auc')

# %%
plot_model(model, plot = 'pr')

# %%
plot_model(model,'confusion_matrix')

# %%
plot_model(model,'class_report')

# %%
plot_model(model,"feature")

# %%
plot_model(model,"error")

# %% [markdown]
# **Export model**

# %%
x_var=get_config("X_train").columns
x_var
# Out:
# Index(['cfl8', 'cfl9', 'visibility4', 'visibility8', 'wind_gust7', 'cft2',
#        'visibility2', 'wind_gust5', 'cfl0', 'cfl1', 'cfm4', 'cfl6', 'cin4',
#        'temp9', 'dir5', 'cfl3', 'lhflx4', 'cfl2', 'cfl5', 'cfl4', 'cfl7',
#        'dir9', 'cin9', 'shflx3', 'visibility9', 'visibility1', 'cape4'],
#       dtype='object')

# %%
#define x and y
Y=df_all4k.prec_l
X=df_all4k[x_var]

# %%
#Run the machine learning model
from sklearn.ensemble import ExtraTreesClassifier
from lightgbm.sklearn import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.1, random_state=1)
#ml_model=ExtraTreesClassifier(n_estimators=150).fit(X_train,y_train)
ml_model=LGBMClassifier(n_estimators=250).fit(X_train,y_train)

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
cr=pd.DataFrame(classification_report(y_test, ml_model.predict(X_test),output_dict=True)).T
plt.figure(figsize=(12, 9))
plt.title("Quality report (Machine Learning)")
sns.heatmap(cr[:-3].drop(columns=["support"]),annot=True,cmap="YlGnBu",fmt='.0%');

# %%
plt.figure(figsize=(8, 6))
plt.title("Confusion matrix (Machine Learning)")
import seaborn as sns
global_sc=pd.crosstab(y_test, ml_model.predict(X_test),margins=True,)
sns.heatmap(global_sc,annot=True,cmap="YlGnBu",fmt='.0f');

# %%
import math
from scipy.stats import entropy
plt.figure(figsize=(12, 9))
plt.title("Precision Machine Learning and entropy")
column_sc=pd.crosstab(y_test, ml_model.predict(X_test), margins=True,normalize="columns")
column_sc=column_sc.append(pd.DataFrame(entropy(column_sc,base=2)/(math.log2(column_sc.shape[0])),columns=["entropy/entropy.max"],
                    index=column_sc.columns).T).rename(columns={"All":"Climatology"})
sns.heatmap(column_sc,annot=True,cmap="YlGnBu",fmt='.0%');

# %%
import pickle
model_dict={"x_var":x_var,"ml_model":ml_model,"coor":coor}
pickle.dump(model_dict, open("prec_LEVX_d1.al", 'wb'))
